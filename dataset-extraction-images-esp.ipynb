# %% [markdown]
# # Ejemplo de extracción de datos
#
# Este notebook utiliza una colección digital descrita a través de ficheros MARCXML que incluye metadatos descriptivos del catálogo [Moving Image Archive](https://data.nls.uk/data/metadata-collections/moving-image-archive/) de la Biblioteca Nacional de Escocia.

# %% [markdown]
# ### Importando las librerías de código

# %%
# https://pypi.org/project/pymarc/
import pymarc, re, csv
import pandas as pd
from pymarc import parse_xml_to_array

# %% [markdown]
# ### Generando un fichero CSV como salida con el contenido procesado

# %%
csv_salida = csv.writer(open('registros_marc.csv', 'w'), delimiter = ',', quotechar = '"', quoting = csv.QUOTE_MINIMAL)
csv_salida.writerow(['titulo', 'autor', 'lugar_produccion', 'fecha', 'extension', 'creditos', 'materias', 'resumen', 'detalles', 'enlace'])
# Out:
# 89

# %% [markdown]
# ### Generando un fichero CSV como salida con el contenido procesado a partir de los archivos originales

# %%
with open('registros_marc.csv', 'w') as csv_sal:
    csv_salida = csv.writer(csv_sal, delimiter = ',', quotechar = '"', quoting = csv.QUOTE_MINIMAL)
    csv_salida.writerow(['titulo', 'autor', 'lugar_produccion', 'fecha', 'extension', 'creditos', 'materias', 'resumen', 'detalles', 'enlace'])


    registros = parse_xml_to_array(open('Moving-Image-Archive/Moving-Image-Archive-dataset-MARC.xml'))

    for registro in registros:

        titulo = autor = lugar_produccion = fecha = extension = creditos = materias = resumen = detalles = enlace =''

        # titulo
        if registro['245'] is not None:
          titulo = registro['245']['a']
          if registro['245']['b'] is not None:
            titulo = titulo + " " + registro['245']['b']

        # autor
        if registro['100'] is not None:
          autor = registro['100']['a']
        elif registro['110'] is not None:
          autor = registro['110']['a']
        elif registro['700'] is not None:
          autor = registro['700']['a']
        elif registro['710'] is not None:
          autor = registro['710']['a']

        # lugar de producción
        if registro['264'] is not None:
          lugar_produccion = registro['264']['a']

        # fecha
        for f in registro.get_fields('264'):
            fechas = f.get_subfields('c')
            if len(fechas):
                fecha = fechas[0]

                if fecha.endswith('.'): fecha = fecha[:-1]


        # Physical Description - extent
        for f in registro.get_fields('300'):
            extension = f.get_subfields('a')
            if len(extension):
                extension = extension[0]
                # TODO cleaning
            detalles = f.get_subfields('b')
            if len(detalles):
                detalles = detalles[0]

        # creditos
        if registro['508'] is not None:
          creditos = registro['508']['a']

        # Resumen
        if registro['520'] is not None:
          resumen = registro['520']['a']

        # Materia
        if registro['653'] is not None:
            materias = '' 
            for f in registro.get_fields('653'):
                materias += f.get_subfields('a')[0] + ' -- '
            materias = re.sub(' -- $', '', materias)


        # enlace
        if registro['856'] is not None:
          enlace = registro['856']['u']


        csv_salida.writerow([titulo,autor,lugar_produccion,fecha,extension,creditos,materias,resumen,detalles,enlace])

# %% [markdown]
# ## Leyendo el fichero CSV

# %%
# Este comando añade el contenido del fichero a un Pandas DataFrame
df = pd.read_csv('registros_marc.csv')

# %% [markdown]
# ## Consultando el contenido

# %%
df
# Out:
#                                     titulo                         autor  \
# 0     (GLASGOW TRAMS AND BOTANIC GARDENS).  RUSSELL, Stanley Livingstone
# 1        (LAST DAY OF THE TRAMS, GLASGOW).                           NaN
# 2                          INTO THE MISTS.                           NaN
# 3             PASSING OF THE TRAMCAR, the.                           NaN
# 4                       SCOTS OF TOMORROW.   Campbell Harper Productions
# ...                                    ...                           ...
# 6012                  CITY OF BIRMINGHAM .                           NaN
# 6013    BUILDING THE BIG DREDGE - STAGE 1.                           NaN
# 6014             ALEXANDER STEPHEN'S YARD.                           NaN
# 6015        QUEEN ELIZABETH  Ship No. 552.                           NaN
# 6016                              RUAHINE.                           NaN
#
#                               lugar_produccion   fecha        extension  \
# 0     [Place of production not identified]  :   1950.0   (2.00 mins) :
# 1     [Place of production not identified]  :   1962.0  (28.00 mins) :
# 2     [Place of production not identified]  :   1956.0  (10.04 mins) :
# 3     [Place of production not identified]  :   1962.0  (63.36 mins) :
# 4     [Place of production not identified]  :   1959.0  (13.00 mins) :
# ...                                        ...     ...              ...
# 6012  [Place of production not identified]  :   1948.0   (6.11 mins) :
# 6013  [Place of production not identified]  :   1964.0   (8min20sec) :
# 6014  [Place of production not identified]  :   1964.0  (11.57 mins) :
# 6015  [Place of production not identified]  :   1940.0   (5min24sec) :
# 6016  [Place of production not identified]  :   1951.0  (12.26 mins) :
#
#                                                creditos  \
# 0     Director, [filmed by Stanley L. Russell, Thame...
# 1                           Director, [filmed by SAAC].
# 2                   Director, [filmed by  W.S. Dobson].
# 3                                                   NaN
# 4                 Producer, Campbell Harper Films Ltd..
# ...                                                 ...
# 6012                                                NaN
# 6013                 Producer, Stephen Group Film Unit.
# 6014                                        Producer, .
# 6015                                                NaN
# 6016                                                NaN
#
#                                                materias  \
# 0     Bus Stations and Depots -- Buses and Coaches, ...
# 1        Transport -- Glasgow -- documentary -- amateur
# 2     Ceremonies -- Emotions, Attitudes and Behaviou...
# 3                    Ceremonies -- Transport -- Glasgow
# 4     Art and Artists, general   -- Education -- edu...
# ...                                                 ...
# 6012  Ceremonies -- Construction and Engineering -- ...
# 6013  Construction and Engineering -- Ships and Ship...
# 6014  Employment, Industry and Industrial Relations ...
# 6015  Employment, Industry and Industrial Relations ...
# 6016  Carriages -- Ceremonies -- Ships and Shipping ...
#
#                                                 resumen  \
# 0     The Botanic Gardens, Glasgow with shots of the...
# 1     Footage of the last trams to run in Glasgow, a...
# 2     The story of the last Edinburgh tram.  Shots o...
# 3     Footage of the last tram to run in Glasgow. Th...
# 4     Scottish school pupils studying scientific and...
# ...                                                 ...
# 6012  Built and engined by John Brown & Co. Ltd.   S...
# 6013  Shots of Indonesian Sea Dredge No. 1, under co...
# 6014  Shots of the Alexander Stephen's yard, and the...
# 6015  Built and engineered by John Brown & Co. Ltd. ...
# 6016  Footage of "Ruahine" ship being launched and t...
#
#                             detalles                                  enlace
# 0                       mute, colour     http://movingimage.nls.uk/film/0001
# 1                     silent, colour     http://movingimage.nls.uk/film/0002
# 2                     silent, colour     http://movingimage.nls.uk/film/0004
# 3                     silent, colour     http://movingimage.nls.uk/film/0005
# 4             sound, black and white     http://movingimage.nls.uk/film/0007
# ...                              ...                                     ...
# 6012                  silent, colour  http://movingimage.nls.uk/film/UCS0195
# 6013                  silent, colour  http://movingimage.nls.uk/film/UCS0204
# 6014                  silent, colour  http://movingimage.nls.uk/film/UCS0207
# 6015         silent, black and white  http://movingimage.nls.uk/film/UCS0213
# 6016  silent, black and white/colour  http://movingimage.nls.uk/film/UCS0214
#
# [6017 rows x 10 columns]

# %% [markdown]
# ### Consultando las columnas

# %%
df.columns
# Out:
# Index(['titulo', 'autor', 'lugar_produccion', 'fecha', 'extension', 'creditos',
#        'materias', 'resumen', 'detalles', 'enlace'],
#       dtype='object')

# %% [markdown]
# ### ¿Cuántos registros existen?

# %%
len(df)
# Out:
# 6017

# %% [markdown]
# ## Explorando las materias
# ### Creamos una lista de materias y la ordenamos alfabéticamente

# %%
df['materias'][2]
# Out:
# 'Ceremonies -- Emotions, Attitudes and Behaviour -- Local Government -- Transport -- Edinburgh -- amateur'

# %%
df['materias'].str.split('--', expand=True).stack()
# Out:
# 0     0                  Bus Stations and Depots
#       1               Buses and Coaches, general
#       2     Celebrations, Traditions and Customs
#       3                     Children and Infants
#       4                   Leisure and Recreation
#                             ...
# 6016  0                                Carriages
#       1                               Ceremonies
#       2                       Ships and Shipping
#       3                           Dunbartonshire
#       4                                 technical
# Length: 23742, dtype: object

# %%
# Obtener valores únicos
materias = pd.unique(df['materias'].str.split(' -- ', expand=True).stack()).tolist()
for materia in sorted(materias, key=str.lower):
    print(materia)
# Out:
# Aberdeen
# Aberdeenshire
# advertising
# Agriculture
# Air displays and shows
# Air Raids
# Aircraft see also Helicopters
# Airports
# amateur
# Angus
# Animals
# animation
# Architecture and Buildings
# Argyllshire
# Art and Artists, general
# Arts and Crafts
# Ayrshire
# Banff
# Berwickshire
# biographical
# Birds
# Borders
# British Empire, the
# Broadcasting, general
# Buddhism
# Bulldozers
# Bus Stations and Depots
# Buses and Coaches, general
# Butchers and Butcher Shops
# Bute
# Cafeterias and Canteens
# Caithness
# Camping
# Canals
# Canoeing
# Carriages
# Celebrations, Traditions and Customs
# Celts and Celtic Culture
# Ceremonies
# Cheese and Cheese Making
# Children and Infants
# children's
# Christmas  see also New Year
# cine mag
# Clackmannanshire
# comedy
# Construction and Engineering
# crime
# Crime, Punishment and Law Enforcement
# dance
# Dentistry
# Depression, the
# Disillusionment
# documentary
# Dumfriesshire
# Dunbartonshire
# Dundee
# East Lothian
# Easter
# Edinburgh
# Education
# educational
# Emotions, Attitudes and Behaviour
# Employment, Industry and Industrial Relations
# Environment
# ethnographic
# experimental
# fantasy
# Ferries
# Fife
# Fire Service
# Fish and Fishing
# Fish Gutting
# Fish Markets
# Fishing Boats
# Fishwives
# Food and Drink
# Forth River
# Glasgow
# Gorbals, the
# Healthcare
# Highland Games
# Highlands, the
# historical
# Hogmanay
# Holiday Camps
# Home Guard
# Home Life
# home movies and videos
# horror
# Housing and Living Conditions
# industrial
# Inner Hebrides
# Institutional Care
# instructional
# Invernesshire
# Kincardineshire
# Kinrosshire
# Kirkudbrightshire
# Lanarkshire
# Landscapes and Seascapes
# Leisure and Recreation
# Lifeboats
# Lobster Fishing
# Local Government
# local topical
# Loch Ness Monster, the
# Media, Communication and the Creative Industries
# medical
# Midlothian
# Military, the
# Morayshire
# Music
# music
# Music Hall
# music video
# Nairn
# newsreel
# Orkney Islands
# Outer Hebrides
# Paddle Steamers
# parody
# Peat and Peat Cutting
# Peebles- shire
# Perth
# Politics
# Power Resources
# promotional
# propaganda
# public information
# Religion
# religion
# Renfrewshire
# Reptiles
# Reservoirs
# Residential Homes for the Elderly
# Restaurants
# Revenge
# Riding of the Marches
# Rodents
# romance
# Ross-shire
# Roxburghshire
# Royalty
# Science and Technology
# science fiction
# scientific
# Selkirkshire
# Shetland Islands
# Ships and Shipping
# Special Needs Education
# Spinning
# sponsored
# Sporting Activities
# sports
# Spring
# Stained Glass
# Stirling
# Stirlingshire
# Sutherland
# technical
# television arts
# television documentary
# television educational
# television entertainment
# television news
# television sport
# Tourism and Travel
# training
# Transport
# travelogue
# War
# War Crimes
# Water and Waterways
# West Lothian
# Wigtownshire
# women film makers

# %%
df['materias']
# Out:
# 0       Bus Stations and Depots -- Buses and Coaches, ...
# 1          Transport -- Glasgow -- documentary -- amateur
# 2       Ceremonies -- Emotions, Attitudes and Behaviou...
# 3                      Ceremonies -- Transport -- Glasgow
# 4       Art and Artists, general   -- Education -- edu...
#                               ...
# 6012    Ceremonies -- Construction and Engineering -- ...
# 6013    Construction and Engineering -- Ships and Ship...
# 6014    Employment, Industry and Industrial Relations ...
# 6015    Employment, Industry and Industrial Relations ...
# 6016    Carriages -- Ceremonies -- Ships and Shipping ...
# Name: materias, Length: 6017, dtype: object

# %% [markdown]
# ### También podemos calcular con qué frecuencia se usa una materia

# %%
# Partir las materias y obtener el número de ocurrencias
materia_contador = df['materias'].str.split(' -- ').apply(lambda x: pd.Series(x).value_counts()).sum().astype('int').sort_values(ascending=False).to_frame().reset_index(level=0)
# Añadimos las columnas
materia_contador.columns = ['materia', 'contador']
# Mostrar con barras horizontales
display(materia_contador.style.bar(subset=['contador'], color='#d65f5f').set_properties(subset=['contador'], **{'width': '300px'}))
# Out:
# <style  type="text/css" >
#     #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.2%, transparent 40.2%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 39.4%, transparent 39.4%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 34.9%, transparent 34.9%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.3%, transparent 33.3%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.2%, transparent 31.2%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.8%, transparent 26.8%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.6%, transparent 26.6%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.4%, transparent 22.4%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.9%, transparent 21.9%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.3%, transparent 20.3%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.1%, transparent 20.1%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.7%, transparent 19.7%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.7%, transparent 18.7%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.7%, transparent 17.7%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.6%, transparent 17.6%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.4%, transparent 17.4%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.4%, transparent 17.4%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.9%, transparent 14.9%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.7%, transparent 14.7%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.4%, transparent 13.4%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.3%, transparent 13.3%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.2%, transparent 13.2%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.0%, transparent 13.0%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.9%, transparent 12.9%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.6%, transparent 12.6%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.1%, transparent 12.1%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.7%, transparent 11.7%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.0%, transparent 11.0%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.9%, transparent 10.9%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.8%, transparent 10.8%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.7%, transparent 10.7%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979830d33row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
#             width:  300px;
#         }    #T_a3d99d8e_efa6_11eb_a26b_94e979
