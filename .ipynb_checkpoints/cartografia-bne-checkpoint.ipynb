# %% [markdown]
# # Ejemplo de extracción de datos
#
# Este notebook utiliza una colección digital descrita a través de ficheros MARCXML que incluye metadatos descriptivos del catálogo [Moving Image Archive](https://data.nls.uk/data/metadata-collections/moving-image-archive/) de la Biblioteca Nacional de Escocia.
#
# La Bibliografía Española de Cartografía es una publicación cuyo objetivo principal es dar a conocer el material cartográfico publicado en España, que ingresa en la Biblioteca Nacional de España a través del Depósito Legal, y que incluye mapas, planos, cartas náuticas, atlas, etc., tanto en formato impreso como electrónico. En el año 2007 se inició la publicación en línea y desde el 2010 se incorporan a esta bibliografía los atlas, antes recogidos en la Bibliografía Española de Monografías. Se publica anualmente y es consultable en línea.
#
# https://datos.gob.es/es/catalogo/e00123904-bibliografia-espanola-de-cartografia-2017

# %% [markdown]
# ### Importando las librerías de código

# %%
# https://pypi.org/project/pymarc/
import pymarc, re, csv
import pandas as pd
from pymarc import parse_xml_to_array
from datapackage import Package

# %% [markdown]
# ### Generando un fichero CSV como salida con el contenido procesado

# %%
csv_salida = csv.writer(open('registros_marc_bne.csv', 'w'), delimiter = ',', quotechar = '"', quoting = csv.QUOTE_MINIMAL)
csv_salida.writerow(['titulo', 'autor', 'lugar_produccion', 'fecha', 'extension', 'creditos', 'materias', 'resumen', 'detalles'])
# Out:
# 82

# %% [markdown]
# ### Leyendo los archivos originales

# %%
registros = parse_xml_to_array(open('BNE-cartografia/BN_CARTOGRAFIA_2017-MARCXML.xml'))

for registro in registros:
    
    titulo = autor = lugar_produccion = fecha = extension = creditos = materias = resumen = detalles =''
    
    # titulo
    if registro['245'] is not None:
      titulo = registro['245']['a']
      if registro['245']['b'] is not None:
        titulo = titulo + " " + registro['245']['b']
    
    # autor
    if registro['100'] is not None:
      autor = registro['100']['a']
    elif registro['110'] is not None:
      autor = registro['110']['a']
    elif registro['700'] is not None:
      autor = registro['700']['a']
    elif registro['710'] is not None:
      autor = registro['710']['a']
    
    # lugar de producción
    if registro['264'] is not None:
      lugar_produccion = registro['264']['a']
    
    # fecha
    for f in registro.get_fields('264'):
        fechas = f.get_subfields('c')
        if len(fechas):
            fecha = fechas[0]
            
            if fecha.endswith('.'): fecha = fecha[:-1]
    
    
    # Physical Description - extent
    for f in registro.get_fields('300'):
        extension = f.get_subfields('a')
        if len(extension):
            extension = extension[0]
            # TODO cleaning
        detalles = f.get_subfields('b')
        if len(detalles):
            detalles = detalles[0]
            
    # creditos
    if registro['508'] is not None:
      creditos = registro['508']['a']
    
    # Resumen
    if registro['520'] is not None:
      resumen = registro['520']['a']
    
    # Materia
    if registro['650'] is not None:
        materias = '' 
        for f in registro.get_fields('650'):
            materias += f.get_subfields('a')[0] + ' -- '
        materias = re.sub(' -- $', '', materias)
    
    
    # enlace
    #if registro['856'] is not None:
    #  enlace = registro['856']['u']
    
    
    csv_salida.writerow([titulo,autor,lugar_produccion,fecha,extension,creditos,materias,resumen,detalles])

# %% [markdown]
# ## Leyendo el fichero CSV

# %%
# Este comando añade el contenido del fichero a un Pandas DataFrame
df = pd.read_csv('registros_marc_bne.csv')

# %% [markdown]
# ## Consultando el contenido

# %%
df
# Out:
#                                                  titulo  \
# 0                                  14 routen um Manacor
# 1                                  14 routes in Manacor
# 2                                  14 rutas por Manacor
# 3                                  14 rutes per Manacor
# 4                                              A Coruña
# ...                                                 ...
# 1241  [Mapa de Asturias] : vuelve al paraíso, ven a ...
# 1242                    [Mapa de carreteras de Galicia]
# 1243                    [Mapa de carreteras de Galicia]
# 1244    [Mapa de carreteras del Principado de Asturias]
# 1245              [Mapa de Dumbría] : Dumbría es Camino
#
#                             autor  lugar_produccion  fecha extension  \
# 0                         Manacor               NaN    NaN    1 mapa
# 1                         Manacor               NaN    NaN    1 mapa
# 2                         Manacor               NaN    NaN    1 mapa
# 3                         Manacor               NaN    NaN    1 mapa
# 4              Turismo de Galicia               NaN    NaN   1 plano
# ...                           ...               ...    ...       ...
# 1241              Recrea Asturias               NaN    NaN    1 mapa
# 1242  Publicaciones Cartográficas               NaN    NaN    1 mapa
# 1243  Publicaciones Cartográficas               NaN    NaN    1 mapa
# 1244                    InterMapa               NaN    NaN    1 mapa
# 1245                      Dumbría               NaN    NaN    1 mapa
#
#       creditos       materias  resumen detalles
# 0          NaN  Excursionismo      NaN     col.
# 1          NaN  Excursionismo      NaN     col.
# 2          NaN  Excursionismo      NaN     col.
# 3          NaN  Excursionismo      NaN     col.
# 4          NaN            NaN      NaN     col.
# ...        ...            ...      ...      ...
# 1241       NaN     Carreteras      NaN     col.
# 1242       NaN     Carreteras      NaN     col.
# 1243       NaN     Carreteras      NaN     col.
# 1244       NaN     Carreteras      NaN     col.
# 1245       NaN            NaN      NaN     col.
#
# [1246 rows x 9 columns]

# %% [markdown]
# ### Consultando las columnas

# %%
df.columns
# Out:
# Index(['titulo', 'autor', 'lugar_produccion', 'fecha', 'extension', 'creditos',
#        'materias', 'resumen', 'detalles'],
#       dtype='object')

# %% [markdown]
# ### ¿Cuántos registros existen?

# %%
len(df)
# Out:
# 1246

# %% [markdown]
# ## Explorando las materias
# ### Creamos una lista de materias y la ordenamos alfabéticamente

# %%
df['materias'][2]
# Out:
# 'Excursionismo'

# %%
df['materias'].str.split(' -- ', expand=True).stack()
# Out:
# 0     0          Excursionismo
# 1     0          Excursionismo
# 2     0          Excursionismo
# 3     0          Excursionismo
# 14    0          Excursionismo
#                   ...
# 1223  0    Escuelas infantiles
# 1241  0             Carreteras
# 1242  0             Carreteras
# 1243  0             Carreteras
# 1244  0             Carreteras
# Length: 583, dtype: object

# %%
# Obtener valores únicos
materias = pd.unique(df['materias'].str.split(' -- ', expand=True).stack()).tolist()
for materia in sorted(materias, key=str.lower):
    print(materia)
# Out:
# Aceite de oliva
# Actividades recreativas al aire libre
# Albergues juveniles
# Alojamientos turísticos
# Arquitectura
# Arquitectura modernista
# Arquitectura románica
# Arte románico
# Aves
# Bares
# Bodegas
# Buceo
# Caminos
# Carreras campo a través (Atletismo)
# Carreras ciclistas
# Carreras de automóviles
# Carreteras
# Centrales hidroeléctricas
# Centros docentes
# Ciclismo
# Ciclismo todoterreno
# Cicloturismo
# Cine
# Cines
# Comarcas
# Comercios
# Costas
# Deportes acuáticos
# Desplazamientos en bicicleta
# Enoturismo
# Escuelas infantiles
# Excursionismo
# Ferrocarriles de alta velocidad
# Ferrocarriles metropolitanos
# Geología
# Geomorfología
# Geoparques
# Hidrogeología
# Hidrología
# Jardines botánicos
# Lengua vasca
# Mantequilla
# Mitología
# Museos
# Nombres geográficos
# Orientación (Deporte)
# Paisaje
# Parques naturales
# Peregrinaciones cristianas
# Pesca de agua dulce
# Piragüismo
# Quesos
# Radiación natural
# Restaurantes
# Rutas literarias
# Sector servicios
# Senderismo
# Sidra
# Suelos
# Surf
# Transportes
# Tráfico
# Usos del suelo
# Vinos
# Vías verdes
# Zonas húmedas
# Zonas industriales

# %% [markdown]
# ### También podemos calcular con qué frecuencia se usa una materia

# %%
# Partir las materias y obterner el número de ocurrencias
materia_contador = df['materias'].str.split(' -- ').apply(lambda x: pd.Series(x).value_counts()).sum().astype('int').sort_values(ascending=False).to_frame().reset_index(level=0)
# Añadimos las columnas
materia_contador.columns = ['materia', 'contador']
# Mostrar con barras horizontales
display(materia_contador.style.bar(subset=['contador'], color='#d65f5f').set_properties(subset=['contador'], **{'width': '300px'}))
# Out:
# <style  type="text/css" >
#     #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.4%, transparent 73.4%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 57.8%, transparent 57.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 57.8%, transparent 57.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.4%, transparent 16.4%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.4%, transparent 16.4%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.5%, transparent 12.5%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.6%, transparent 8.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.0%, transparent 7.0%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.7%, transparent 4.7%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.9%, transparent 3.9%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.9%, transparent 3.9%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 3.1%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 3.1%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 3.1%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 3.1%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.3%, transparent 2.3%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.3%, transparent 2.3%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_18ecf210_b3e8_11eb_bfd5_94e979830d33row35_col1 {
#             width:  10em;
